# %% [markdown]
# # Exploratory Data Analysis (EDA)
# is the first and most important step in the Machine Learning pipeline. It involves analyzing and visualizing data to understand its structure, patterns, relationships, and potential issues before applying any machine learning models.
#
# * The following are Univariate analysis on Categorical Data and Numerial Data ( the dataset is baisc titanic dataset for understanding purpose)

# %% [markdown]
# # 1. UNIVARIATE ANALYSIS
#
# It's a syatistical technique used to analyze & sumerize a single variable(INDEPENDENT) in a dataset.
# * often done by visualizing through plots

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\AdityaRaj Sharma\\Python Data sets\\titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# # a. countplot

# %%
df['Survived']

# %% [markdown]
# Show the row numbers of survival and non-survival
# * 0 for Non- Survival
# * 1 for Survival

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %% [markdown]
# # plot the survival count

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x='Survived', data=df, palette='coolwarm')

# Add title and labels
plt.title("Survival Count in Titanic Dataset")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # IT shows the survival count over male and female

# %%
sns.countplot(x='Survived', data=df, hue = "Sex", palette='coolwarm')

# Add title and labels
plt.title("Survival Count in Titanic Dataset")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Analysis for Pclass
#
# * 1 - upper class
# * 2 - middle class
# * 3  - lower class

# %%
sns.countplot(x = 'Pclass', data = df,palette  = 'coolwarm')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Titanic dataset
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# Count of each class
pclass_counts = df['Pclass'].value_counts()

# Labels and colors
labels = ['Third Class', 'First Class', 'Second Class']
colors = ['#ff9999','#66b3ff','#99ff99']

# Plot pie chart
plt.figure(figsize=(6,6))
plt.pie(pclass_counts, labels=labels, autopct='%1.1f%%', colors=colors, startangle=90, shadow=True)

# Title
plt.title("Passenger Class Distribution on Titanic")
plt.show()

# %% [markdown]
# # Analysis for Gender

# %%
sns.countplot(x = "Sex", data = df, palette = 'coolwarm')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# # b. Pie Chart

# %%
df['Pclass'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# # a. Histogram

# %%
import matplotlib.pyplot as plt

plt.hist(df['Age'])
plt.show()
# plt.hist(df['Age'],bins = 20)

# %% [markdown]
# # b. Distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\AdityaRaj Sharma\AppData\Local\Temp\ipykernel_12332\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# C:\Users\AdityaRaj Sharma\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # c. box plot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df['Age'].min()
# Out:
# 0.17

# %%
df['Age'].max()
# Out:
# 76.0

# %%
df['Age'].mean()
# Out:
# 30.272590361445783

# %%
df['Age'].skew()
# Out:
# 0.4573612871503845

# %% [markdown]
# if perfect 0 then its perfect skewed
